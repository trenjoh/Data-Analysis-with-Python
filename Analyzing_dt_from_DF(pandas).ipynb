# %% [markdown]
# <a href="https://colab.research.google.com/github/trenjoh/Data-Analysis-with-Python/blob/main/Analyzing_dt_from_DF(pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # ANALYZING DATA FROM DATAFRAMES

# %%
import pandas as pd

# %%
dt = pd.read_csv('/content/drive/My Drive/Colab Notebooks/weather_data_updated.csv',header=0)
print(dt.head(10))
# Out:
#        Town  Min_temp(°C)  Max_temp(°C) Temperature Category
# 0   Nairobi          14.0          22.0                 warm
# 1   Mombasa          22.0          29.0            very warm
# 2    Kisumu          20.0          26.0                 warm
# 3    Nakuru          14.0          20.0                 cold
# 4   Eldoret          16.0          23.0                 warm
# 5     Thika          15.0          21.0                 cold
# 6     Nyeri          16.0          25.0                 warm
# 7  Machakos          17.0          25.0                 warm
# 8      Meru          23.0          33.0            very warm
# 9      Embu          25.0          30.0            very warm

# %%
Total_towns = dt['Town'].count()
print(  f'The total numbers of towns {Total_towns}')
# Out:
# The total numbers of towns 24

# %%
Average_min_temp = dt["Min_temp(°C)"].mean()
print(f'The average minimum temperature is {Average_min_temp}')
# Out:
# The average minimum temperature is 18.5

# %%
Average_max_temp =dt['Max_temp(°C)'].mean()
print(f"The Average maximum temperature is {Average_max_temp:.1f}")
# Out:
# The Average maximum temperature is 25.9

# %%
Total_min_temp = dt['Min_temp(°C)'].sum()
print(f'The total minimum temperature is {Total_min_temp}')
# Out:
# The total minimum temperature is 444.0

# %%
Max_min_temp = dt['Min_temp(°C)'].max()
print(f'The max minimum temperature is {Max_min_temp}')
# Out:
# The max minimum temperature is 27.0

# %%
High_temperature_rec = dt[dt['Max_temp(°C)'] >30]
print(High_temperature_rec)
# Out:
#        Town  Min_temp(°C)  Max_temp(°C) Temperature Category
# 8      Meru          23.0          33.0            very warm
# 10  Kericho          27.0          33.0            very warm
# 13  Malindi          25.0          34.0            very warm
# 16  Nanyuki          25.0          32.0            very warm

# %%
from IPython.display import display
with pd.option_context('display.max_rows', 6):
  display(dt[dt['Max_temp(°C)']>29])
# Out:
#         Town  Min_temp(°C)  Max_temp(°C) Temperature Category
# 8       Meru          23.0          33.0            very warm
# 9       Embu          25.0          30.0            very warm
# 10   Kericho          27.0          33.0            very warm
# 13   Malindi          25.0          34.0            very warm
# 15  Kakamega          20.0          30.0            very warm
# 16   Nanyuki          25.0          32.0            very warm

# %% [markdown]
# # Displaying the grouped and aggregated dataframe

# %%
# Grouping by 'Temperature Category' and calculate the mean of 'Min_temp(°C)' and 'Max_temp(°C)'
grouped_dt = dt.groupby('Temperature Category').agg({
    'Min_temp(°C)': 'mean',
    'Max_temp(°C)': 'mean'
}).round(2)

# Display the grouped and aggregated dataframe
print(grouped_dt)
# Out:
#                       Min_temp(°C)  Max_temp(°C)
# Temperature Category
# cold                         14.50         20.75
# very warm                    23.86         31.57
# warm                         16.85         24.46

# %%
# Sort by 'Min_temp(°C)' in ascending order
sorted_dt_min = dt.sort_values(by='Min_temp(°C)', ascending=True)
sorted_dt_min.tail(4)
# Out:
#        Town  Min_temp(°C)  Max_temp(°C) Temperature Category
# 13  Malindi          25.0          34.0            very warm
# 16  Nanyuki          25.0          32.0            very warm
# 9      Embu          25.0          30.0            very warm
# 10  Kericho          27.0          33.0            very warm

# %% [markdown]
# # MERGING DIFFERNT DATA FRAMES.

# %%
# Dataframe 1 (df1)
data1 = {
    'Town': ['Nairobi', 'Mombasa', 'Kisumu', 'Nakuru'],
    'Min_temp(°C)': [14.0, 22.0, 20.0, 14.0],
    'Max_temp(°C)': [22.0, 29.0, 26.0, 20.0]
}
df1 = pd.DataFrame(data1)

# Dataframe 2 (df2)
data2 = {
    'Town': ['Nairobi', 'Mombasa', 'Eldoret', 'Nyeri'],
    'Population': [4500000, 1200000, 290000, 300000],
    'Elevation(m)': [1795, 50, 2100, 1780]
}
df2 = pd.DataFrame(data2)

# %%
merged_df = pd.merge(df1, df2, on='Town', how='left')
merged_df
# Out:
#       Town  Min_temp(°C)  Max_temp(°C)  Population  Elevation(m)
# 0  Nairobi          14.0          22.0   4500000.0        1795.0
# 1  Mombasa          22.0          29.0   1200000.0          50.0
# 2   Kisumu          20.0          26.0         NaN           NaN
# 3   Nakuru          14.0          20.0         NaN           NaN

# %%
merged_df = pd.merge(df1, df2, on='Town', how='right')
merged_df
# Out:
#       Town  Min_temp(°C)  Max_temp(°C)  Population  Elevation(m)
# 0  Nairobi          14.0          22.0     4500000          1795
# 1  Mombasa          22.0          29.0     1200000            50
# 2  Eldoret           NaN           NaN      290000          2100
# 3    Nyeri           NaN           NaN      300000          1780

# %%
merged_df = pd.merge(df1, df2, on='Town', how='inner')
merged_df
# Out:
#       Town  Min_temp(°C)  Max_temp(°C)  Population  Elevation(m)
# 0  Nairobi          14.0          22.0     4500000          1795
# 1  Mombasa          22.0          29.0     1200000            50

# %%
merged_df = pd.merge(df1, df2, on='Town', how='outer')
merged_df
# Out:
#       Town  Min_temp(°C)  Max_temp(°C)  Population  Elevation(m)
# 0  Eldoret           NaN           NaN    290000.0        2100.0
# 1   Kisumu          20.0          26.0         NaN           NaN
# 2  Mombasa          22.0          29.0   1200000.0          50.0
# 3  Nairobi          14.0          22.0   4500000.0        1795.0
# 4   Nakuru          14.0          20.0         NaN           NaN
# 5    Nyeri           NaN           NaN    300000.0        1780.0
