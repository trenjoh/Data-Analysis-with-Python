# %% [markdown]
# <a href="https://colab.research.google.com/github/trenjoh/Data-Alysis-with-Python/blob/main/Data_retrieval_d_frame(pandas)_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
dt = pd.read_csv('/content/drive/My Drive/Colab Notebooks/weather_data_updated.csv',header=0)
print(dt)
# Out:
#         Town  Min_temp(°C)  Max_temp(°C) Temperature Category
# 0    Nairobi          14.0          22.0                 warm
# 1    Mombasa          22.0          29.0            very warm
# 2     Kisumu          20.0          26.0                 warm
# 3     Nakuru          14.0          20.0                 cold
# 4    Eldoret          16.0          23.0                 warm
# 5      Thika          15.0          21.0                 cold
# 6      Nyeri          16.0          25.0                 warm
# 7   Machakos          17.0          25.0                 warm
# 8       Meru          23.0          33.0            very warm
# 9       Embu          25.0          30.0            very warm
# 10   Kericho          27.0          33.0            very warm
# 11  Naivasha          16.0          28.0                 warm
# 12    Kitale          24.0          28.0                 warm
# 13   Malindi          25.0          34.0            very warm
# ...

# %%
dt['Town'][12]
# Out:
# 'Kitale'

# %%
dt.columns
# Out:
# Index(['Town', 'Min_temp(°C)', 'Max_temp(°C)', 'Temperature Category'], dtype='object')

# %%
dt.at[12,'Town']
# Out:
# 'Kitale'

# %%
dt.Town[23]
# Out:
# 'mukima'

# %%
dt_sub = dt[['Town', 'Min_temp(°C)', 'Max_temp(°C)']]
print(dt_sub.iloc[7:10])
# Out:
#        Town  Min_temp(°C)  Max_temp(°C)
# 7  Machakos          17.0          25.0
# 8      Meru          23.0          33.0
# 9      Embu          25.0          30.0

# %%
dt.loc[1:3]
# Out:
#       Town  Min_temp(°C)  Max_temp(°C) Temperature Category
# 1  Mombasa          22.0          29.0            very warm
# 2   Kisumu          20.0          26.0                 warm
# 3   Nakuru          14.0          20.0                 cold

# %%
dt.head(2)
# Out:
#       Town  Min_temp(°C)  Max_temp(°C) Temperature Category
# 0  Nairobi          14.0          22.0                 warm
# 1  Mombasa          22.0          29.0            very warm

# %%
dt.tail(2)
# Out:
#        Town  Min_temp(°C)  Max_temp(°C) Temperature Category
# 22  Bungoma          17.0          25.0                 warm
# 23   mukima          14.0          23.0                 warm

# %%
print(dt[dt['Min_temp(°C)'] > 25])
# Out:
#        Town  Min_temp(°C)  Max_temp(°C) Temperature Category
# 10  Kericho          27.0          33.0            very warm

# %%
dt_copy = dt.copy()
